# %% [markdown]
# # Shercliff_3D_duct test case

# %% [markdown]
# ## Introduction
#
#  Validation made by: matthieu
#
#  Report generated 01/02/2026

# %% [markdown]
# ### Description
#
# Comparison with the analytical solutions from Shercliff's 1953 paper.

# %%
from trustutils import run

run.TRUST_parameters("1.9.7")

# %%
from trustutils import run

run.reset()
run.addCase(".","jdd.data",nbProcs=1)
run.printCases()
run.runCases()

# %% [markdown]
# ## Computer Performance

# %%
run.tablePerf()

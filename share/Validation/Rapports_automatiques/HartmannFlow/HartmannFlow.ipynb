# %% [markdown]
# # Hartmann Flow test case

# %% [markdown]
# ## Introduction
#
#  Validation made by: matthieu
#
#  Report generated 14/12/2025

# %% [markdown]
# ### Description

# %%
from trustutils import run

run.TRUST_parameters("1.9.6")

# %%
from trustutils import run

run.reset()
run.addCase(".","jdd.data",nbProcs=1)
run.printCases()
run.runCases()

# %% [markdown]
# ## Computer Performance

# %%
run.tablePerf()
